# %%
# !git clone https://github.com/Bazina/BiGCN.git
# Out:
# Cloning into 'BiGCN'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 139 (delta 56), reused 115 (delta 45), pack-reused 2
# Receiving objects: 100% (139/139), 100.09 MiB | 20.23 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
# !pip install torch-scatter torch-sparse torch_cluster torch_geometric -f https://data.pyg.org/whl/torch-2.1.0+${CUDA}.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.0 MB/s eta 0:00:00
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl size=3571340 sha256=6e72216afd58d5d5a9a5c2b2595d41db4c9c1eedace9b777dae0c11598902147
#   Stored in directory: /root/.cache/pip/wheels/92/f1/2b/3b46d54b134259f58c8363568569053248040859b1a145b3ce
# ...
#   Created wheel for torch-sparse: filename=torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl size=2659121 sha256=36ea37ae8afa93cf8b6a51c10effbf84451b01cf7e25d3bfa850859c5af8dfe3
# ...

# %%
# !sh BiGCN/main.sh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 9.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# huggingface-hub 0.19.4 requires tqdm>=4.42.1, but you have tqdm 4.40.0 which is incompatible.
# imbalanced-learn 0.10.1 requires joblib>=1.1.1, but you have joblib 0.14.1 which is incompatible.
# panel 1.3.4 requires tqdm>=4.48.0, but you have tqdm 4.40.0 which is incompatible.
# ...

# %%
# !sh BiGCN/main.sh
# Out:
# ...
# reading twitter tree
# tree no: 3098
# loading tree label
# 818
# 205 205 207 201
# loading dataset
# 100% 818/818 [00:13<00:00, 59.70it/s]
# loading tree label
# 818
# 205 205 207 201
# reading twitter tree
# tree no: 3098
# loading train set
# train no: 646
# loading test set
# test no: 162
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...
